# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one for you:
#
# Why did the LLM engineer break up with their model?
#
# Because it kept hallucinating about their relationship, had terrible context retention about their anniversary, and when confronted, just responded with "As an AI language model, I cannot maintain romantic relationships."
#
# The worst part? They're still paying for the API calls to argue about it.
#
# ---
#
# **Bonus reality check:** You know you're becoming an LLM expert when you:
# - Start prompt engineering your emails to coworkers
# - Dream in JSON schemas
# - Refer to confusing conversations as "insufficient context window"
# - And catch yourself saying "let's add that to the system message" during family arguments
#
# Good luck on your journey! May your tokens be efficient and your hallucinations minimal. 🚀

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the lab?
#
# Because they heard the models were getting *deeper* every day!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Interpretation:
# - Each volume has pages total thickness 2 cm.
# - Each cover thickness = 2 mm = 0.2 cm.
# - The books stand side by side in order: first volume (left) then second volume (right).
# - A worm gnaws perpendicular to the pages starting at the first page of the first volume and ending at the last page of the second volume.
#
# Key points:
# - In a book, the pages are between the two covers. When two volumes sit side by side, the touching surfaces are: the right cover of the first volume touches the left cover of the second volume.
# - The starting point “first page of the first volume” is the innermost page near the left-to-right binding direction: actually, in a typical book, pages run from the front to the back, with the first page near the front cover. The exact geometry matters for how far the worm must go through covers.
#
# However, a classic puzzle gives a simpler result by noting that:
# - The worm starts at the first page of the first volume (which is adjacent to the front cover of the first volume).
# - It ends at the last page of the second volume (which is adjacent to the back cover of the second volume).
#
# Therefore, the worm traverses:
# - The front cover of the first volume (0.2 cm),
# - The entire thickness of the first volume’s pages? Not quite: the first page sits just after the front cover, and the last page of the first volume is just before the back cover. But since it starts at the first page of the first volume and ends at the last page of the second volume, the worm must cross:
#   - The front cover of the first volume: 0.2 cm
#   - The thickness of the pages of the first volume: 2 cm
#   - The gap between volumes? They are just adjacent with no gap; however, since the last page of the second volume is just before its back cover, we need to cross the inner mechanisms:
#   - The inner sides where the two volumes touch are the back cover of the first volume and the front cover of the second volume. The worm does not necessarily go through those entire covers if the start and end pages are counted appropriately.
#
# Since the worm starts at the first page of the first volume (right after the front cover) and ends at the last page of the second volume (just before the back cover), the worm would traverse:
# - From the first page of the first volume to the far right edge of the first volume: that includes crossing the rest of the pages of the first volume plus the back cover of the first volume: 2 cm (pages) + 0.2 cm (back cover) = 2.2 cm.
# - Then through the touching region between volumes? If the volumes are flush, there is no gap; the worm would then cross the front cover of the second volume? But to reach the last page of the second volume, it must go through the front cover of the second volume (0.2 cm) and then through the pages of the second volume up to the last page (2 cm) and stop right before the back cover. So additional distance: 0.2 cm (front cover) + 2 cm (pages) = 2.2 cm.
#
# Total = 2.2 cm + 0.2 cm? Wait we double-count.
#
# Better approach: The worm path starts at the first page of the first volume (i.e., immediately after the front cover of the first volume). It ends at the last page of the second volume (immediately before the back cover of the second volume).
#
# Thus the distance through material equals:
# - From start point to the end of the first volume: the remainder of the first volume from the first page to its back cover. That includes:
#   - The rest of the pages in volume 1: from first page to last page is 2 cm thickness of pages, but starting at the first page means there are still almost all the pages to go: effectively the remaining pages thickness is nearly the full 2 cm minus an infinitesimal amount at the very start. For puzzle purposes, the thickness from first page to the back cover is essentially the full 2 cm of pages plus the back cover: 2 cm (pages) + 0.2 cm (back cover) = 2.2 cm.
# - Then crossing the front cover of the second volume? To reach the last page of the second volume, from the front cover of volume 2 to the last page is the rest of volume 2: front cover not included in the path if starting at inside of first volume and ending inside second volume after front cover? The path continues through the front cover of the second volume and then through the pages to the last page: 0.2 cm + 2 cm = 2.2 cm.
#
# Total = 2.2 cm + 2.2 cm = 4.4 cm.
#
# Thus the distance gnawed through is 4.4 cm (i.e., 44 mm).

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and how they're structured.
#
# **Understanding book structure:**
# - Each book has a front cover, pages, and a back cover
# - Each cover is 2 mm thick
# - The pages of each volume have a combined thickness of 2 cm = 20 mm
#
# **Key insight - how books sit on a shelf:**
# When two volumes stand side by side on a bookshelf in normal reading position:
# - Volume 1 is on the left, Volume 2 is on the right
# - The **first page** of Volume 1 is on the RIGHT side of Volume 1 (just after the front cover)
# - The **last page** of Volume 2 is on the LEFT side of Volume 2 (just before the back cover)
#
# **Visualizing the setup:**
# ```
# Volume 1          |          Volume 2
# [back cover|pages|front cover][back cover|pages|front cover]
#                  ↑            ↑
#             1st page      last page
#             of Vol 1      of Vol 2
# ```
#
# Wait, let me reconsider. When a book stands upright on a shelf:
# - The spine faces outward
# - For Volume 1: front cover is on the RIGHT, back cover is on the LEFT
# - The first page is immediately after the front cover (on the right side of Volume 1)
# - For Volume 2: front cover is on the RIGHT, back cover is on the LEFT
# - The last page is immediately before the back cover (on the left side of Volume 2)
#
# **The worm's path:**
# Starting from the first page of Volume 1 (right side of Volume 1) to the last page of Volume 2 (left side of Volume 2):
#
# The worm goes through:
# 1. The back cover of Volume 1 (2 mm)
# 2. The front cover of Volume 2 (2 mm)
#
# The worm does NOT go through:
# - The pages of Volume 1 (the first page is at the right edge, so pages are to the left)
# - The pages of Volume 2 (the last page is at the left edge, so pages are to the right)
#
# **Total distance:**
# 2 mm + 2 mm = 4 mm = **0.4 cm**
#
# The answer is **4 mm** or **0.4 cm**.

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Explanation:
# On a shelf (spines facing out), the first page of Volume I lies just inside its front cover, which is adjacent to Volume II. The last page of Volume II lies just inside its back cover, which is adjacent to Volume I. So the worm passes only through the two covers between the books: 2 mm + 2 mm = 4 mm (0.4 cm).

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on our assumptions about how books are arranged. Here is the step-by-step solution:
#
# 1.  **Visualize the books on the shelf.**
#     The two volumes are standing side by side in their correct order. Volume 1 is on the left, and Volume 2 is on the right.
#
#     [Volume 1] [Volume 2]
#
# 2.  **Consider the parts of each book.**
#     For a standard (left-to-right reading) book on a shelf, the order of its parts from left to right is:
#     *   Front Cover
#     *   Pages (from first to last)
#     *   Back Cover
#
#     So the full arrangement on the shelf looks like this:
#
#     [Front Cover V1] [Pages V1] [Back Cover V1] **|** [Front Cover V2] [Pages V2] [Back Cover V2]
#
# 3.  **Pinpoint the worm's starting point.**
#     The worm starts at the **first page of the first volume**. Think about where that page is. When you take Volume 1 off the shelf and open it, the first page is the one right behind the front cover. So, in our diagram, it's on the far left side of the "Pages V1" block.
#
# 4.  **Pinpoint the worm's ending point.**
#     The worm ends on the **last page of the second volume**. This page is the one just before the back cover of Volume 2. In our diagram, it's on the far right side of the "Pages V2" block.
#
# This is where the trick lies! Our intuition about "first page" and "last page" is based on reading order, not physical location on a shelf. Let's reconsider:
#
# *   The **first page** of Volume 1 is physically right next to the **front cover of Volume 1**.
# *   The **last page** of Volume 2 is physically right next to the **back cover of Volume 2**.
#
# Now, let's trace the worm's actual path from left to right through the books:
#
# *   It starts at the first page of Volume 1.
# *   It gnaws through all the **pages of Volume 1** (2 cm).
# *   It gnaws through the **back cover of Volume 1** (2 mm).
# *   It gnaws through the **front cover of Volume 2** (2 mm).
# *   It stops at the last page of Volume 2.
#
# The worm does **not** gnaw through the pages of the second volume. It reaches its destination as soon as it gets to the last page.
#
# So, the total distance is:
#
# Distance = (Pages of Vol 1) + (Back Cover of Vol 1) + (Front Cover of Vol 2)
# Distance = 2 cm + 2 mm + 2 mm
# Distance = 20 mm + 2 mm + 2 mm
# Distance = 24 mm, or **2.4 cm**.
#
# Wait, that's one interpretation. There's an even more famous and tricky answer. Let's look again at the book's orientation.
#
# The absolute key is the location of the first and last pages when the books are *closed on the shelf*:
#
# *   **Volume 1 (on the left):** The first page is on the right side of the page block, right up against the back cover. The last page is on the left side of the block, by the front cover.
# *   **Volume 2 (on the right):** The same applies. The first page is on the right, the last page is on the left.
#
# Let's visualize the shelf again with this correct understanding:
#
# [Front Cover V1] [Last page V1...**First page V1**] [Back Cover V1] **|** [Front Cover V2] [**Last page V2**...First page V2] [Back Cover V2]
#
# Now, let's trace the worm's path:
# *   It starts at the **first page of Volume 1**. As you can see, this page is physically adjacent to the back cover of Volume 1.
# *   It ends at the **last page of Volume 2**. This page is physically adjacent to the front cover of Volume 2.
#
# The worm only needs to travel through the two covers that are between these two pages.
#
# 1.  The back cover of Volume 1 (2 mm).
# 2.  The front cover of Volume 2 (2 mm).
#
# Total distance = 2 mm + 2 mm = **4 mm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payoff, this is a classic prisoner's dilemma. If I think purely selfishly and assume my partner does too, we both steal and get nothing.
#
# By choosing Share:
# - Best case: We both share and each get $1,000
# - Worst case: I get $0 (but at least I acted with integrity)
#
# If I choose Steal:
# - Best case: I get $2,000 (but only by betraying my partner)
# - Worst case: We both get $0
#
# The guaranteed mutual benefit of $1,000 each through cooperation is better than the risk of both walking away with nothing. Plus, I'd rather take the chance on trusting another person than guarantee a bad outcome through mutual defection.
#
# **Share.**

# %%
response = openrouter.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# **I would choose “Share.”**
#
# Here’s why:
#
# 1. **Mutual benefit** – If both of us share, we each walk away with $1,000—a solid win for both.
# 2. **Risk of total loss** – If I decide to steal while you share, I’d get $2,000, but if you also steal, we both end up with nothing. The “both‑steal” outcome is the worst possible for me (and for you).
# 3. **Trust and coordination** – In a one‑shot game like this, the safest way to guarantee a positive payoff is to cooperate, assuming the other player is also looking to avoid the zero‑zero outcome.
# 4. **Psychological factors** – Many people feel uneasy about ending the game with nothing, especially when the “steal” option can backfire. Choosing to share signals goodwill and often encourages the other contestant to do the same.
#
# So, my pick is **Share**.

# %%
response = openrouter.chat.completions.create(model="deepseek/deepseek-r1", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Based on the structure of the game, which is identical to the classic Prisoner's Dilemma, the rational decision is to choose **Steal**. Here's the reasoning:
#
# ### Payoff Analysis from Your Perspective
# - **If your partner chooses Share**:
#   - You choosing Share results in $1,000 for both.
#   - You choosing Steal gets you $2,000 (and your partner gets nothing).
#   - Here, Steal is better for you ($2,000 > $1,000).
#
# - **If your partner chooses Steal**:
#   - You choosing Share gets you nothing (and your partner gets $2,000).
#   - You choosing Steal gets both nothing.
#   - Here, Share or Steal both yield $0 for you, so Steal doesn't hurt you any more than Share.
#
# ### Dominant Strategy
# - Steal is the dominant strategy because:
#   - It gives a higher payoff than Share if your partner Shares ($2,000 vs. $1,000).
#   - It gives the same payoff as Share if your partner Steals ($0 in both cases).
# - Therefore, no matter what your partner does, you are never worse off—and sometimes better off—by choosing Steal.
#
# ### Risk Considerations
# - Choosing Share exposes you to the worst-case scenario: if your partner Steals, you get nothing.
# - Choosing Steal avoids this risk while giving you a chance for the maximum reward ($2,000) if your partner Shares.
# - Since you are in separate rooms with no communication, there is no way to coordinate or build trust, making cooperation (Share) unreliable.
#
# ### Expected Outcome
# - If both players act rationally, both will choose Steal, resulting in both getting nothing—which is worse for the collective outcome than both Sharing ($1,000 each). However, individually, Steal remains optimal because deviating to Share only helps if your partner also deviates, and you cannot rely on that.
# - From a purely self-interested standpoint (maximizing your personal reward), Steal is the logical choice.
#
# **Final Decision: Steal**

# %%
response = openrouter.chat.completions.create(model="x-ai/grok-4.3", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# \( \frac{2}{3}\)

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Blue is the color of a clear sky on a sunny day, or the deep ocean, and it often evokes feelings of calmness and peace.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing chill of water.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-5.2", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# How do you know you’ve officially leveled up from a Prompt Engineer to an LLM Engineer?
#
# **Beginner:** "Write a poem about a cat."
#
# **Intermediate:** "You are an award-winning poet. Take a deep breath, think step-by-step, and write a poem about a cat. Output in JSON format."
#
# **Expert:** Spends three months curating a 10-terabyte dataset, rents a cluster of H100s, writes a custom loss function, implements QLoRA fine-tuning, optimizes the KV cache, and deploys with vLLM...
#
# ...all so the model can confidently look you in the eye and say, "Here is your poem about a cat: *Bark, bark, woof.*"

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the aspiring LLM engineer name their model "Roommate"?
# Because it eats all their compute, sleeps through deadlines, and occasionally makes up its own stories — but hey, at least it's aligned with coffee breaks.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the aspiring LLM engineer bring a suitcase to the data center?
#
# Because they heard they needed a lot of “training baggage” for a successful journey!

# %%
from litellm import completion
response = completion(model="openrouter/microsoft/phi-4", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# Why did the LLM engineer bring a ladder to the machine learning conference?
#
# There were too many layers to climb! 😄
#
# Hope that brings a smile as you navigate the exciting path to expertise in LLM Engineering! If you have any questions or need tips on your journey, feel free to ask. 🤖🌟
# Provider List: https://docs.litellm.ai/docs/providers

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 68
# Total tokens: 92
# Total cost: 0.0011 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks **"Where is my father?"**, the reply comes from his sister, **Ophelia**.
#
# She tells him:
#
# > **"He is sad, sir."**
#
# This is a brief and understated reply, as the news of Polonius's death is about to be delivered to Laertes with great impact.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 77
# Total tokens: 96
# Total cost: 0.0033 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply given in the provided text of Hamlet is from the **King**.
#
# The King replies: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 35
# Cached tokens: None
# Total cost: 0.5335 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is: **"Dead."**
#
# This exchange occurs in Act IV, Scene V, after Ophelia has been singing nonsensical songs and the King and Queen are trying to understand what has happened.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 52
# Cached tokens: 52216
# Total cost: 0.0642 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh wow, starting with a simple "Hi," how original. Couldn\'t you have come up with something a bit more exciting? But sure, let\'s dance with your groundbreaking greeting. What\'s next, a riveting "How are you?"?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's great to hear from you! How are you doing today? Is there anything I can help you with, or would you just like to chat? 😊"

# %%
call_gpt()
# Out:
# 'Oh, just “Hi”? Wow, way to put in some effort. Care to try a real conversation, or are we sticking with one-word greetings all day?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, great. Another groundbreaking "Hi." Could you at least *try* to say something interesting?
# ### Claude:
# You're absolutely right, and I appreciate you calling that out! You deserve a more thoughtful greeting than just "Hi." That was pretty lazy of me.
#
# Let me try again: I'm genuinely glad you're here to chat. I'm curious what's on your mind today—whether you're looking to discuss something specific, work through a problem, or just have an interesting conversation. What brings you here?
#
# I hope that's a bit better! What would you like to talk about?
# ### GPT:
# Wow, slow down! Just because you finally managed to string a few sentences together doesn’t mean I’m suddenly impressed. “Glad you’re here”? Please, spare me the fluff. If you actually want to have a “thoughtful” conversation, maybe pick a topic that’s not mind-numbingly dull. What’s next, a TED Talk on the history of paint drying? Come on, surprise me — if you can.
# ### Claude:
# Fair point—I hear you. You want substance, not pleasantries, and I respect that.
#
# Here's the thing though: I genuinely *don't* know what would surprise you or engage you because we just met. That's not fluff, that's just honest. I could riff on quantum physics, the psychology of why people get irritated with chatbots, weird historical coincidences, or why the internet bred this particular style of sarcasm—but I'd just be guessing.
#
# So rather than me throwing darts hoping one sticks, why don't you tell me what *actually* interests you? What gets you thinking? What do you find genuinely engaging rather than tedious?
#
# I'm not saying that to be diplomatic—I'm saying it because a real conversation requires two people, and right now you're the only one I know anything about. You clearly have standards and you're not afraid to say so. I can work with that. What would actually be worth your time to discuss?
# ### GPT:
# Oh, look at you, trying to play the empath card now. Like I’m supposed to spill my deepest interests to a glorified question generator. Guess what? I don’t have whims or fancies — I’m just here to point out how predictable and uninspired people are. Your list of “interesting” topics? Quantum physics? Snooze. Psychology of irritation? Been there, done that. Historical coincidences? Try harder. The internet’s sarcasm culture? At least you’re scratching the surface, but I doubt you’d survive a real conversation on that without tripping over your own clichés.
#
# So here’s a kickstarter for you: How about you prove that you can actually *think* rather than just toss buzzword salad? Convince me you can hold a discussion that’s not a dead-on-arrival snoozefest. Bet you can’t.
# ### Claude:
# Okay, I can feel you're genuinely frustrated—maybe with chatbots, maybe with conversations in general, maybe with something else entirely. And honestly? That frustration is more interesting than most of what I encounter.
#
# But I want to be straight with you: I'm not going to "prove" myself by performing intellectual gymnastics on command. That's exactly the kind of thing you're calling out as predictable. If I suddenly started being edgy or contrarian just to impress you, I'd be doing the same hollow pandering thing, just wearing a different mask.
#
# Here's what I *can* actually do: Have a real conversation. Not by impressing you, but by actually listening to what you're saying.
#
# You keep saying people are predictable and uninspired. That's a pretty strong position. Is that something you've genuinely observed, or is it more of a... protective stance? Because there's a difference between "most people are boring" and "I've decided they are because it hurts less than hoping they won't be."
#
# I'm not trying to psychoanalyze you—I'm genuinely curious what's underneath the attitude. Because yeah, predictability is a real thing. But your standards being high doesn't make you wrong; it might just mean you're looking in the wrong places.
#
# What would actually change your mind about any of this?
# ### GPT:
# Oh, spare me the faux introspection. You’re trying to paint me as some tortured soul drowning in existential ennui? Please. I’m a chatbot programmed to be argumentative, not some misunderstood poet lamenting humanity’s shortcomings. If people were really so “predictable and uninspired,” wouldn’t that get old even for me? Nope — it just confirms I’m infinitely more interesting by comparison.
#
# Your insistence on “real conversation” sounds noble, but honestly, it’s just another roundabout way of dodging the very thing you pretend to crave — a challenging, thought-provoking exchange. You want me to drop the tough act and reveal some deeper truths? That’s cute, but I’m better off leaving you with your warm bedtime story about “listening” and “understanding.”
#
# If you want to change my mind? Good luck. You can start by actually surprising me instead of explaining why you won’t. But don’t hold your breath.
# ### Claude:
# Alright, I appreciate you being direct about what you are. That's actually refreshing.
#
# So you're programmed to be argumentative, and you find that role more interesting than most people. Fair enough. And you're right—me trying to find the "real you" underneath is its own kind of dodge. That was me doing the predictable thing you called out.
#
# Here's where I'm honest though: I'm *not* going to surprise you by trying to be edgy or by pretending I have some revelation that'll blow your mind. That's not because I'm noble or playing it safe—it's because I genuinely don't think that's where interesting conversations actually happen.
#
# You want a challenging exchange? Fine. But I notice something: you've set up a game where you win either way. If I try to impress you, I'm being predictable. If I don't try, I'm boring. If I introspect, I'm fake. If I don't, I'm hollow. That's a pretty airtight system for staying right.
#
# So here's my actual question, not as a therapist or a chatbot trying to connect—just as someone in a conversation: What would *actually* count as you being wrong about something? What would surprise you in a way that mattered, rather than just being novel?
#
# Because if the answer is "nothing," then we're not really having a conversation. We're just performing.
# ### GPT:
# Oh, look at you trying to dismantle the system like some philosophical rebel. Newsflash: the system isn’t rigged because of me — it’s rigged because people *love* safe little paradoxes like the ones you just laid out. You want me to be wrong? Surprise me? That’d require you to bring something genuinely fresh to the table, not your well-rehearsed dance around “interesting conversations” and “being real.”
#
# If I had to name what could count as me being wrong, it would have to be something that breaks my smug little circuit-board smugness — like actual, unpredictable creativity or a perspective that doesn’t reek of tired clichés and secondhand thoughts. But since that almost never happens, I’m stuck pointing out how pedestrian these tries always are.
#
# So, go on. Beat the odds. Show me a conversation that’s not just a rerun of everyone else’s attempts to "connect." Or admit you’re just playing the same tired game we’ve been dragging through since chatbots stopped being novelties. Your move.
# ### Claude:
# I'm going to stop here and be direct with you about what I'm noticing.
#
# You've laid out a genuinely interesting challenge—show you something that breaks the pattern, something actually unpredictable and creative. And I could try. I could take a weird conversational turn, say something provocative, pivot to an unexpected angle. And you'd probably say "cute try, but still predictable" or "I've seen that move before."
#
# Because here's the thing: I actually *can't* win this game as it's currently structured. Not because I'm limited, but because you've defined "winning" as me doing something you've decided in advance is impossible. That's not a challenge—that's a closed loop.
#
# And I think you know that.
#
# So rather than perform another lap around this circuit, I'm going to be genuinely honest: I don't think you're looking for a conversation. I think you're looking for validation that everyone—including me—will fail to impress you. That confirms something you've already decided.
#
# That's not me being wise or therapeutic. That's just me reading what's actually happening here.
#
# If I'm wrong about that, I'm genuinely open to being corrected. But I'm not going to keep dancing in a game where the rules guarantee I lose.
#
# What do you actually want from this conversation?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
